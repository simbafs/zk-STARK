# %%
[2**i % 5 for i in range(1, 5)]
# Out:
# [2, 4, 3, 1]

# %%
set([2**i % 17 for i in range(1, 17)])
# Out:
# {1, 2, 4, 8, 9, 13, 15, 16}

# %%
set([13**i % 17 for i in range(4)])
# Out:
# {1, 4, 13, 16}

# %%
[3**i % 17 for i in range(17-1)]
# Out:
# [1, 3, 9, 10, 13, 5, 15, 11, 16, 14, 8, 7, 4, 12, 2, 6]

# %%
3**4 % 17
# Out:
# 13
